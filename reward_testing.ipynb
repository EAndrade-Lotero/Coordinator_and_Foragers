# %%
from helper_classes import WealthTracker

# %%
sliders = {
    "overhead":0.5,
    "wages":0.5,
    "prerogative":0.5
}
wealth = WealthTracker()
wealth.initialize(sliders)
# Out:
# Number of coins:  700
# Remaining after overhead: 350.0
# Wages: 175.0
# Foragers wealth: [175. 175.]

# %%
wealth.get_coordinator_wealth()
# Out:
# 350.0

# %%
wealth.get_forager_wealth(0)
# Out:
# np.float64(175.0)
